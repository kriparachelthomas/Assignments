# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read the dataset to python environment

# %%
dataset = pd.read_excel('iris.xls')

# %%
dataset
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dataset.size
# Out:
# 750

# %% [markdown]
# # 2.Display the columns in the dataset

# %%
dataset.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # 3. Calculate the mean of each coloumn of the dataset

# %%
dataset.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4. Check for the null values present in the dataset

# %%
dataset.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
dataset.isna()       #isna shows true if it contains null values
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset

# %% [markdown]
# # 1) KDE Plot

# %%
dataset[['PW','PL']].plot.kde()
plt.title('plot between Petal width and petal length')
# Out:
# Text(0.5, 1.0, 'plot between Petal width and petal length')

# %%
dataset[['SW','SL']].plot.kde()
plt.title('plot between Sepal width and Sepal length')
# Out:
# Text(0.5, 1.0, 'plot between Sepal width and Sepal length')

# %% [markdown]
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.

# %% [markdown]
# # 2)Scatter plot

# %%
plt.figure(figsize=(6,4))
plt.scatter(dataset['SW'],dataset['SL'],s=10)
plt.title('Plot of SW VS SL',fontsize=16)
plt.style.use('classic')
plt.grid()
plt.xlabel('SW')
plt.ylabel('SL')
# Out:
# Text(0, 0.5, 'SL')

# %%
plt.figure(figsize=(6,4))
plt.scatter(dataset['PW'],dataset['PL'],s=10)
plt.title('Plot of PW VS PL',fontsize=16)
plt.style.use('classic')
plt.grid()
plt.xlabel('PW')
plt.ylabel('PL')
# Out:
# Text(0, 0.5, 'PL')

# %% [markdown]
# # 3) Histogram

# %%
plt.figure(figsize=(6,6))
plt.hist(dataset['SL'],color='red',rwidth=0.9)
plt.title('Distribution of SL',fontsize=16)
plt.xlabel('SL')
plt.ylabel('Frequency')
plt.xticks()
plt.yticks()
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(6,6))
plt.hist(dataset['SW'],color='blue',rwidth=0.9)
plt.title('Distribution of SW',fontsize=16)
plt.xlabel('SW')
plt.ylabel('Frequency')
plt.xticks()
plt.yticks()
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(6,6))
plt.hist(dataset['PL'],color='green',rwidth=0.9)
plt.title('Distribution of PL',fontsize=16)
plt.xlabel('PL')
plt.ylabel('Frequency')
plt.xticks()
plt.yticks()
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(6,6))
plt.hist(dataset['PW'],color='yellow',rwidth=0.9)
plt.title('Distribution of PW',fontsize=16)
plt.xlabel('PW')
plt.ylabel('Frequency')
plt.xticks()
plt.yticks()
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # 4)Pairplot

# %%
sns.pairplot(dataset)

# %%
sns.pairplot(dataset,hue='Classification')

# %% [markdown]
# # 5) Box plots

# %%
sns.boxplot(x='Classification',y='PL',data=dataset)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PL'>

# %%
sns.boxplot(x='Classification',y='PW',data=dataset)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PW'>

# %%
sns.boxplot(x='Classification',y='SL',data=dataset)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SL'>

# %%
sns.boxplot(x='Classification',y='SW',data=dataset)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SW'>

# %% [markdown]
# # 6)heatmap

# %%
sns.heatmap(dataset.corr(),annot=True)
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5]),
#  [Text(0.5, 0, 'SL'),
#   Text(1.5, 0, 'SW'),
#   Text(2.5, 0, 'PL'),
#   Text(3.5, 0, 'PW')])

# %% [markdown]
# Petal width and petal length have high correlations.
# Petal length and sepal width have good correlations.
# Petal Width and Sepal length have good correlations.

# %% [markdown]
# From these visualizations it is clear that the iris dataset is a balanced dataset.

# %% [markdown]
# #Submitted by,
# Kripa Rachel Thomas
# Norka_DSA_B3_2021
